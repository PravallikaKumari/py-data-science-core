# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
store=pd.read_csv(r"C:\Users\gbrah\Downloads\archive (1)\Sample Superstore Orders.csv")

# %%
store
# Out:
#              Category             City Country/Region    Customer Name  \
# 0           Furniture        Henderson  United States      Claire Gute
# 1           Furniture        Henderson  United States      Claire Gute
# 2     Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3           Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4     Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
# ...               ...              ...            ...              ...
# 9989       Technology      Los Angeles  United States       Ben Ferrer
# 9990       Technology      Los Angeles  United States       Ben Ferrer
# 9991       Technology    Santa Barbara  United States    Maria Etezadi
# 9992       Technology             Yuma  United States      Gary Hansen
# 9993       Technology       Louisville  United States   Sharelle Roach
#
#       Order Date        Order ID  Postal Code Region      Segment   Ship Date  \
# ...

# %%
id(store)
# Out:
# 2442633731344

# %%
len(store)
# Out:
# 9994

# %%
store.shape
# Out:
# (9994, 19)

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Order Date',
#        'Order ID', 'Postal Code', 'Region', 'Segment', 'Ship Date',
#        'Ship Mode', 'State', 'Sub-Category', 'Year Label', 'Days to Ship',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
len(store.columns)
# Out:
# 19

# %%
store.isnull()
# Out:
#       Category   City  Country/Region  Customer Name  Order Date  Order ID  \
# 0        False  False           False          False       False     False
# 1        False  False           False          False       False     False
# 2        False  False           False          False       False     False
# 3        False  False           False          False       False     False
# 4        False  False           False          False       False     False
# ...        ...    ...             ...            ...         ...       ...
# 9989     False  False           False          False       False     False
# 9990     False  False           False          False       False     False
# 9991     False  False           False          False       False     False
# 9992     False  False           False          False       False     False
# 9993     False  False           False          False       False     False
#
# ...

# %%
store.isnull().sum()
# Out:
# Category           0
# City               0
# Country/Region     0
# Customer Name      0
# Order Date         0
# Order ID           0
# Postal Code       11
# Region             0
# Segment            0
# Ship Date          0
# Ship Mode          0
# State              0
# Sub-Category       0
# Year Label         0
# Days to Ship       0
# Discount           0
# Profit             0
# Quantity           0
# Sales              0
# dtype: int64

# %%
store[:]
# Out:
#              Category             City Country/Region    Customer Name  \
# 0           Furniture        Henderson  United States      Claire Gute
# 1           Furniture        Henderson  United States      Claire Gute
# 2     Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3           Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4     Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
# ...               ...              ...            ...              ...
# 9989       Technology      Los Angeles  United States       Ben Ferrer
# 9990       Technology      Los Angeles  United States       Ben Ferrer
# 9991       Technology    Santa Barbara  United States    Maria Etezadi
# 9992       Technology             Yuma  United States      Gary Hansen
# 9993       Technology       Louisville  United States   Sharelle Roach
#
#       Order Date        Order ID  Postal Code Region      Segment   Ship Date  \
# ...

# %%
store[0:10]
# Out:
#           Category             City Country/Region    Customer Name  \
# 0        Furniture        Henderson  United States      Claire Gute
# 1        Furniture        Henderson  United States      Claire Gute
# 2  Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3        Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4  Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
# 5        Furniture      Los Angeles  United States  Brosina Hoffman
# 6  Office Supplies      Los Angeles  United States  Brosina Hoffman
# 7       Technology      Los Angeles  United States  Brosina Hoffman
# 8  Office Supplies      Los Angeles  United States  Brosina Hoffman
# 9  Office Supplies      Los Angeles  United States  Brosina Hoffman
#
#    Order Date        Order ID  Postal Code Region    Segment   Ship Date  \
# 0   11/8/2021  CA-2021-152156      42420.0  South   Consumer  11/11/2021
# ...

# %%
store[0:20:5]
# Out:
#            Category         City Country/Region    Customer Name  Order Date  \
# 0         Furniture    Henderson  United States      Claire Gute   11/8/2021
# 5         Furniture  Los Angeles  United States  Brosina Hoffman    6/9/2019
# 10        Furniture  Los Angeles  United States  Brosina Hoffman    6/9/2019
# 15  Office Supplies   Fort Worth  United States    Harold Pawlan  11/22/2020
#
#           Order ID  Postal Code   Region      Segment   Ship Date  \
# 0   CA-2021-152156      42420.0    South     Consumer  11/11/2021
# 5   CA-2019-115812      90032.0     West     Consumer   6/14/2019
# 10  CA-2019-115812      90032.0     West     Consumer   6/14/2019
# 15  US-2020-118983      76106.0  Central  Home Office  11/26/2020
#
#          Ship Mode       State Sub-Category  Year Label  Days to Ship  \
# 0     Second Class    Kentucky    Bookcases        2021             3
# 5   Standard Class  California  Furnishings        2019             5
# ...

# %%
store.head()
# Out:
#           Category             City Country/Region    Customer Name  \
# 0        Furniture        Henderson  United States      Claire Gute
# 1        Furniture        Henderson  United States      Claire Gute
# 2  Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3        Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4  Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
#
#    Order Date        Order ID  Postal Code Region    Segment   Ship Date  \
# 0   11/8/2021  CA-2021-152156      42420.0  South   Consumer  11/11/2021
# 1   11/8/2021  CA-2021-152156      42420.0  South   Consumer  11/11/2021
# 2   6/12/2021  CA-2021-138688      90036.0   West  Corporate   6/16/2021
# 3  10/11/2020  US-2020-108966      33311.0  South   Consumer  10/18/2020
# 4  10/11/2020  US-2020-108966      33311.0  South   Consumer  10/18/2020
#
#         Ship Mode       State Sub-Category  Year Label  Days to Ship  \
# ...

# %%
store.head(3)
# Out:
#           Category         City Country/Region    Customer Name Order Date  \
# 0        Furniture    Henderson  United States      Claire Gute  11/8/2021
# 1        Furniture    Henderson  United States      Claire Gute  11/8/2021
# 2  Office Supplies  Los Angeles  United States  Darrin Van Huff  6/12/2021
#
#          Order ID  Postal Code Region    Segment   Ship Date     Ship Mode  \
# 0  CA-2021-152156      42420.0  South   Consumer  11/11/2021  Second Class
# 1  CA-2021-152156      42420.0  South   Consumer  11/11/2021  Second Class
# 2  CA-2021-138688      90036.0   West  Corporate   6/16/2021  Second Class
#
#         State Sub-Category  Year Label  Days to Ship  Discount    Profit  \
# 0    Kentucky    Bookcases        2021             3       0.0   41.9136
# 1    Kentucky       Chairs        2021             3       0.0  219.5820
# 2  California       Labels        2021             4       0.0    6.8714
#
#    Quantity   Sales
# 0         2  261.96
# 1         3  731.94
# ...

# %%
store.tail()
# Out:
#         Category           City Country/Region   Customer Name  Order Date  \
# 9989  Technology    Los Angeles  United States      Ben Ferrer  12/24/2019
# 9990  Technology    Los Angeles  United States      Ben Ferrer   7/12/2019
# 9991  Technology  Santa Barbara  United States   Maria Etezadi    6/6/2021
# 9992  Technology           Yuma  United States     Gary Hansen  10/16/2022
# 9993  Technology     Louisville  United States  Sharelle Roach   4/17/2022
#
#             Order ID  Postal Code Region      Segment   Ship Date  \
# 9989  US-2019-138247      90045.0   West  Home Office  12/29/2019
# 9990  CA-2019-110184      90036.0   West  Home Office   7/16/2019
# 9991  CA-2021-160717      93101.0   West  Home Office   6/11/2021
# 9992  CA-2022-159282      85364.0   West  Home Office  10/21/2022
# 9993  CA-2022-134845      80027.0   West  Home Office   4/23/2022
#
#            Ship Mode       State Sub-Category  Year Label  Days to Ship  \
# ...

# %%
store.isna()
# Out:
#       Category   City  Country/Region  Customer Name  Order Date  Order ID  \
# 0        False  False           False          False       False     False
# 1        False  False           False          False       False     False
# 2        False  False           False          False       False     False
# 3        False  False           False          False       False     False
# 4        False  False           False          False       False     False
# ...        ...    ...             ...            ...         ...       ...
# 9989     False  False           False          False       False     False
# 9990     False  False           False          False       False     False
# 9991     False  False           False          False       False     False
# 9992     False  False           False          False       False     False
# 9993     False  False           False          False       False     False
#
# ...

# %% [markdown]
# # Introudce statistical concept in pandas ==>

# %%
store.describe()
# Out:
#         Postal Code   Year Label  Days to Ship     Discount       Profit  \
# count   9983.000000  9994.000000   9994.000000  9994.000000  9994.000000
# mean   55245.233297  2020.722233      3.958475     0.156203    28.656896
# std    32038.715955     1.123555      1.747603     0.206452   234.260108
# min     1040.000000  2019.000000      0.000000     0.000000 -6599.978000
# 25%    23223.000000  2020.000000      3.000000     0.000000     1.728750
# 50%    57103.000000  2021.000000      4.000000     0.200000     8.666500
# 75%    90008.000000  2022.000000      5.000000     0.200000    29.364000
# max    99301.000000  2022.000000      7.000000     0.800000  8399.976000
#
#           Quantity         Sales
# count  9994.000000   9994.000000
# mean      3.789574    229.858001
# std       2.225110    623.245101
# min       1.000000      0.444000
# 25%       2.000000     17.280000
# 50%       3.000000     54.490000
# 75%       5.000000    209.940000
# max      14.000000  22638.480000
