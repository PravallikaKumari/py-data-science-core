# %%
import pandas as pd

# %% [raw]
# #movies = pd.read_csv(r'C:\Users\Admin\Downloads\archive\movie.csv')

# %%
movies = pd.read_csv(r"C:\Users\gbrah\Downloads\Projects\archive\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.head(1)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %% [raw]
# #ratings = pd.read_csv(r'C:\Users\Admin\Downloads\archive\rating.csv')

# %%
ratings = pd.read_csv(r"C:\Users\gbrah\Downloads\Projects\archive\rating.csv")

# %%
ratings.shape
# Out:
# (20000263, 4)

# %% [raw]
# #tags = pd.read_csv(r'C:\Users\Admin\Downloads\archive\tag.csv')

# %%
tags = pd.read_csv(r"C:\Users\gbrah\Downloads\Projects\archive\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (27278, 3)
# (20000263, 4)
# (465564, 4)

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.iloc[1]
# Out:
# userId            65
# movieId          208
# tag        dark hero
# Name: 1, dtype: object
